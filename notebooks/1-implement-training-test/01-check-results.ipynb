# %% [markdown]
# # check results

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

from metric import get_metric
from param import *

sns.set_style("darkgrid")

# %% [markdown]
# ## load results

# %%
results_path = ParamDir().OUTPUT_DIR
with open(results_path/"lr_results.pickle", "rb") as f:
    results = pickle.load(f)

# %%
results.keys()
# Out:
# dict_keys(['y_pred', 'y_test', 'estimator'])

# %% [markdown]
# ## evaluation

# %%
scorer = get_metric(ParamEval().metric_name)
scorer(results['y_pred'], results['y_test'])
# Out:
# 0.41521550347319874

# %% [markdown]
# ## visualize quality pred

# %%
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(results['y_test'], label="test", c="gray", marker="o", markersize=2)
ax.scatter(range(len(results['y_pred'])),results['y_pred'], label="pred", c="brown", s=5)
